# %%
import kagglehub

path = kagglehub.dataset_download("berkayalan/ecommerce-sales-dataset")

print(path, "is downloaded")
# Out:
# ...
# 100%|██████████| 271k/271k [00:00<00:00, 290kB/s]
# Extracting files...
# C:\Users\admin\.cache\kagglehub\datasets\berkayalan\ecommerce-sales-dataset\versions\1 is downloaded

# %%
import os

os.listdir(path)
# Out:
# ['basket_details.csv', 'customer_details.csv']

# %%
import pandas as pd

# %%
basket_df = pd.read_csv(os.path.join(path, "customer_details.csv"), sep=",")

# %%
customer_df = pd.read_csv(os.path.join(path, "basket_details.csv"), sep=",")
